# %%
print("Heil Hitlier")
# Out:
# Heil Hitlier

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import numpy as np
from sklearn.datasets import load_iris

iris = load_iris()
X, y = iris.data, iris.target

print("ขนาดข้อมูล", X.shape)
print("สิ่งที่วัด", iris.feature_names)
print("สายพันธุ์", iris.target_names)
print("จำนวนต่อสายพันธุ์", np.bincount(y))
print("ค่าต่ำสุดแต่ละคอลัมน์", X.min(axis=0))
print("ค่าสูงสุดแต่ละคอลัมน์", X.max(axis=0))
# Out:
# ขนาดข้อมูล (150, 4)
# สิ่งที่วัด ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# สายพันธุ์ ['setosa' 'versicolor' 'virginica']
# จำนวนต่อสายพันธุ์ [50 50 50]
# ค่าต่ำสุดแต่ละคอลัมน์ [4.3 2.  1.  0.1]
# ค่าสูงสุดแต่ละคอลัมน์ [7.9 4.4 6.9 2.5]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

print("กองฝึก", len(X_train), "ดอก")
print("กองสอบ", len(X_test), "ดอก")
print("เฉลยในกองฝึก", np.bincount(y_train))
print("เฉลยในกองสอบ", np.bincount(y_test))
# Out:
# กองฝึก 105 ดอก
# กองสอบ 45 ดอก
# เฉลยในกองฝึก [31 37 37]
# เฉลยในกองสอบ [19 13 13]

# %%
from sklearn.dummy import DummyClassifier

baseline = DummyClassifier(strategy="most_frequent")
baseline.fit(X_train, y_train)

print("คำตอบ 5 ข้อแรกของนักเรียนหลับตาเดา", baseline.predict(X_test[:5]))
print("คะแนนเดามั่ว", baseline.score(X_test, y_test))
# Out:
# คำตอบ 5 ข้อแรกของนักเรียนหลับตาเดา [1 1 1 1 1]
# คะแนนเดามั่ว 0.28888888888888886

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

print("คะแนนต้นไม้", model.score(X_test, y_test))
# Out:
# คะแนนต้นไม้ 1.0

# %%
from sklearn.tree import export_text

print(export_text(model, feature_names=iris.feature_names))
# Out:
# |--- petal length (cm) <= 2.45
# |   |--- class: 0
# |--- petal length (cm) >  2.45
# |   |--- petal length (cm) <= 4.75
# |   |   |--- petal width (cm) <= 1.60
# |   |   |   |--- class: 1
# |   |   |--- petal width (cm) >  1.60
# |   |   |   |--- class: 2
# |   |--- petal length (cm) >  4.75
# |   |   |--- petal width (cm) <= 1.75
# |   |   |   |--- petal length (cm) <= 4.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- petal length (cm) >  4.95
# |   |   |   |   |--- petal width (cm) <= 1.55
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- petal width (cm) >  1.55
# |   |   |   |   |   |--- petal length (cm) <= 5.45
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- petal length (cm) >  5.45
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- petal width (cm) >  1.75
# |   |   |   |--- petal length (cm) <= 4.85
# |   |   |   |   |--- sepal width (cm) <= 3.10
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- sepal width (cm) >  3.10
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- petal length (cm) >  4.85
# |   |   |   |   |--- class: 2

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(14, 8))
plot_tree(model, feature_names=iris.feature_names,
          class_names=iris.target_names, filled=True)
plt.show()

# %%
new_flowers = np.array([
    [5.0, 3.4, 1.4, 0.2],
    [6.0, 2.9, 4.5, 1.5],
    [6.5, 3.0, 5.8, 2.2],
])

pred = model.predict(new_flowers)
print("คำตอบ", pred)
print("ชื่อสายพันธุ์", [iris.target_names[p] for p in pred])
# Out:
# คำตอบ [0 1 2]
# ชื่อสายพันธุ์ [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')]

# %%
print("คะแนนเมื่อสอบด้วยกองฝึก", model.score(X_train, y_train))
print("คะแนนเมื่อสอบด้วยกองสอบ", model.score(X_test, y_test))
# Out:
# คะแนนเมื่อสอบด้วยกองฝึก 1.0
# คะแนนเมื่อสอบด้วยกองสอบ 1.0

# %%
from sklearn.datasets import load_wine

wine = load_wine()

Xw = wine.data
yw = wine.target

print("\n===== ด่าน 9 =====")
print("ขนาดข้อมูลไวน์", Xw.shape)
print("จำนวนแต่ละสายพันธุ์", np.bincount(yw))

Xw_train, Xw_test, yw_train, yw_test = train_test_split(
    Xw,
    yw,
    test_size=0.3,
    random_state=42
)

wine_model = DecisionTreeClassifier(random_state=42)
wine_model.fit(Xw_train, yw_train)

train_score = wine_model.score(Xw_train, yw_train)
test_score = wine_model.score(Xw_test, yw_test)

print("คะแนนกองฝึก =", round(train_score,4))
print("คะแนนกองสอบ =", round(test_score,4))
print("ผลต่าง =", round(train_score-test_score,4))
# Out:
# ===== ด่าน 9 =====
# ขนาดข้อมูลไวน์ (178, 13)
# จำนวนแต่ละสายพันธุ์ [59 71 48]
# คะแนนกองฝึก = 1.0
# คะแนนกองสอบ = 0.963
# ผลต่าง = 0.037

# %%
X_leak = np.vstack([Xw_train, Xw_test])
y_leak = np.concatenate([yw_train, yw_test])

leak_model = DecisionTreeClassifier(random_state=42)
leak_model.fit(X_leak, y_leak)

print("คะแนนของโมเดลที่เห็นข้อสอบล่วงหน้า", round(leak_model.score(Xw_test, yw_test), 4))
# Out:
# คะแนนของโมเดลที่เห็นข้อสอบล่วงหน้า 1.0

# %%
for rs in [0, 1, 7, 42, 100]:
    a, b, c, d = train_test_split(Xw, yw, test_size=0.3, random_state=rs)
    m = DecisionTreeClassifier(random_state=42).fit(a, c)
    print("random_state", rs, "ได้คะแนน", round(m.score(b, d), 4))
# Out:
# random_state 0 ได้คะแนน 0.9259
# random_state 1 ได้คะแนน 0.9074
# random_state 7 ได้คะแนน 0.9074
# random_state 42 ได้คะแนน 0.963
# random_state 100 ได้คะแนน 0.8148

# %%
plt.figure(figsize=(18,10))
plot_tree(
    wine_model,
    feature_names=wine.feature_names,
    class_names=wine.target_names,
    filled=True
)
plt.show()

# %%
print("\n========== คำตอบสั้น ๆ ==========")
# ข้อ 1
correct = int(round(baseline.score(X_test, y_test) * len(y_test)))
print("1. เลข 0.2888 มาจาก", correct, "/", len(y_test),
      "=", round(correct / len(y_test), 4))
# ข้อ 2
print("2. กฎข้อแรกของต้นไม้คือ color_intensity <= 3.82")
print("   และสามารถแยกสายพันธุ์ class_2 ออกจากกลุ่มอื่นได้")
# ข้อ 3
difference = train_score - test_score
print("3. คะแนนกองฝึก =", round(train_score, 4))
print("   คะแนนกองสอบ =", round(test_score, 4))
print("   ต่างกัน =", round(difference, 4))
print("   คะแนนกองสอบเป็นค่าที่สะท้อนความสามารถจริงของโมเดล")
# ข้อ 4
print("4. ตัวอย่าง Data Leakage")
print("   เช่น นำข้อมูลที่เกิดขึ้นหลังลูกค้ายกเลิกบริการ")
print("   เช่น วันที่ยกเลิกบัญชี มาใช้ฝึกโมเดล")
print("   ทำให้โมเดลเหมือนรู้คำตอบล่วงหน้า")
# Out:
# ========== คำตอบสั้น ๆ ==========
# 1. เลข 0.2888 มาจาก 13 / 45 = 0.2889
# 2. กฎข้อแรกของต้นไม้คือ color_intensity <= 3.82
#    และสามารถแยกสายพันธุ์ class_2 ออกจากกลุ่มอื่นได้
# 3. คะแนนกองฝึก = 1.0
#    คะแนนกองสอบ = 0.963
#    ต่างกัน = 0.037
#    คะแนนกองสอบเป็นค่าที่สะท้อนความสามารถจริงของโมเดล
# 4. ตัวอย่าง Data Leakage
#    เช่น นำข้อมูลที่เกิดขึ้นหลังลูกค้ายกเลิกบริการ
#    เช่น วันที่ยกเลิกบัญชี มาใช้ฝึกโมเดล
#    ทำให้โมเดลเหมือนรู้คำตอบล่วงหน้า
